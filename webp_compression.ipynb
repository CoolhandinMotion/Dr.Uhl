# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
from numpy.typing import NDArray
from PIL import Image

# %%
def get_image(file_path:Path)-> NDArray|None:
    if os.path.isfile(file_path) and file_name.lower().endswith(".png"):
        image = Image.open(file_path)
        if image.mode == "RGBA":
            image = image.convert("RGB")
            # array = np.array(image)
        return image
    print("returned none")
    return None

def save_webp_img(img:Image,name:str,quality: int) -> None:
    img.save(os.path.join(destinationFolder, f"{name}.webp"),format="WEBP",quality=quality)

def get_image_size(folder:Path,base_name:str,format:str) -> int:
    test_image_path = os.path.join(folder, f"{base_name}.{format}")
    test_image_size = os.path.getsize(test_image_path) / 1000
    return np.around(test_image_size,decimals=2)

def remove_image(folder:Path,base_name:str,format:str):
    file_path = os.path.join(folder, f"{base_name}.{format}")
    os.remove(file_path)

# %%
sourceFolder = "cropped_images"
destinationFolder = "compressed_draft"

if not os.path.exists(destinationFolder):
    os.makedirs(destinationFolder)

sorted_sourcefolder_walk = sorted(os.listdir(sourceFolder), key=lambda x: int(x[:-4]))

# %%
desired_webp_size_kb = 50


tolerated_file_size_deviation = 2
base_webp_quality= 60
webp_quality_step = 3

webp_qualities_dict : dict[str:int] = {}
webp_max_quality = 100
webp_min_quality = 0



for file_name in sorted_sourcefolder_walk:
    file_path = os.path.join(sourceFolder, file_name)
    image= get_image(file_path)
    base_name = os.path.splitext(file_name)[0]
    png_size = get_image_size(sourceFolder,base_name,'png')
    "Some pictures are too small, meaning even with highest compression ratio they do not reach our desired size on disk"
    if png_size < 3.5* desired_webp_size_kb:
        continue
    "First attempt to compress to desired file size."
    save_webp_img(img=image,name=base_name,quality=base_webp_quality)
    webp_size = get_image_size(destinationFolder,base_name,'webp')
    file_size_one_step_before = 0
    reached_webp_quality = False
    new_webp_quality = base_webp_quality
    while not reached_webp_quality:

        if np.abs(webp_size-desired_webp_size_kb) < tolerated_file_size_deviation:
            webp_qualities_dict[base_name] = new_webp_quality
            image.close()
            print(f"{base_name} was below threshold")
            break

        elif webp_size < desired_webp_size_kb:
            """we should increase webp quality to reach desired file size on disk. """
            new_webp_quality += webp_quality_step
            save_webp_img(img=image,name=base_name,quality=new_webp_quality)
            webp_size = get_image_size(destinationFolder,base_name,'webp')
            "Below statement means if we have overdone the fine tuning and previous step was actually better. restore previous step"
            if np.abs(file_size_one_step_before - desired_webp_size_kb) <= np.abs(webp_size-desired_webp_size_kb):

                if not np.abs(webp_size-desired_webp_size_kb) < tolerated_file_size_deviation:
                    remove_image(destinationFolder,base_name,'webp')
                    break

                print(f"{base_name} with quality {new_webp_quality} overshoot")
                save_webp_img(img=image,name=base_name,quality=new_webp_quality - webp_quality_step)
                webp_qualities_dict[base_name] = new_webp_quality - webp_quality_step
                image.close()
                break
                
            elif new_webp_quality >= 98:

                if not np.abs(webp_size-desired_webp_size_kb) < tolerated_file_size_deviation:
                    remove_image(destinationFolder,base_name,'webp')
                    break

                webp_qualities_dict[base_name] = new_webp_quality
                image.close()
                print(f"{base_name} used highest quality !!!")
                break

            file_size_one_step_before = webp_size

        elif webp_size > desired_webp_size_kb:
            """we should decrease webp quality to reach desired file size on disk. """
            new_webp_quality -= webp_quality_step
            save_webp_img(img=image,name=base_name,quality=new_webp_quality)
            webp_size = get_image_size(destinationFolder,base_name,'webp')

            if np.abs(file_size_one_step_before - desired_webp_size_kb) <= np.abs(webp_size-desired_webp_size_kb):

                if not np.abs(webp_size-desired_webp_size_kb) < tolerated_file_size_deviation:
                    remove_image(destinationFolder,base_name,'webp')
                    break

                print(f"{base_name} with quality {new_webp_quality} overshoot")
                save_webp_img(img=image,name=base_name,quality=new_webp_quality + webp_quality_step)
                webp_qualities_dict[base_name] = new_webp_quality + webp_quality_step
                image.close()
                break
            elif new_webp_quality <= 3:

                if not np.abs(webp_size-desired_webp_size_kb) < tolerated_file_size_deviation:
                    remove_image(destinationFolder,base_name,'webp')
                    break

                webp_qualities_dict[base_name] = new_webp_quality
                image.close()
                print(f"{base_name} used lowest quality !!!")
                break

            file_size_one_step_before = webp_size
# Out:
# 1 was below threshold
# 3 was below threshold
# 4 was below threshold
# 5 was below threshold
# 6 was below threshold
# 8 was below threshold
# 10 was below threshold
# 11 was below threshold
# 13 was below threshold
# 15 was below threshold
# 16 was below threshold
# 17 was below threshold
# 18 was below threshold
# 19 was below threshold
# 20 was below threshold
# 21 was below threshold
# 25 was below threshold
# 27 was below threshold
# 28 was below threshold
# 30 was below threshold
# 31 was below threshold
# 33 was below threshold
# 34 was below threshold
# 37 was below threshold
# 38 was below threshold
# 39 was below threshold
# 41 was below threshold
# 43 was below threshold
# 45 was below threshold
# 46 was below threshold
# 47 was below threshold
# 49 was below threshold
# 51 was below threshold
# 53 was below threshold
# 55 was below threshold
# 56 was below threshold
# 57 used highest quality !!!
# 59 was below threshold
# 60 was below threshold
# 61 was below threshold
# 66 was below threshold
# 68 was below threshold
# 71 was below threshold
# 72 was below threshold
# 74 was below threshold
# 77 was below threshold
# 78 was below threshold
# 79 was below threshold
# 80 was below threshold
# 81 was below threshold
# 82 was below threshold
# 83 was below threshold
# 84 was below threshold
# 85 was below threshold
# 87 was below threshold
# 88 was below threshold
# 90 was below threshold
# 92 was below threshold
# 94 was below threshold
# 97 was below threshold
# 98 was below threshold
# 99 was below threshold
# 100 was below threshold
# 103 was below threshold
# 104 was below threshold
# 105 was below threshold
# 106 was below threshold
# 110 was below threshold
# 111 was below threshold
# 112 was below threshold
# 113 was below threshold
# 114 was below threshold
# 115 was below threshold
# 116 was below threshold
# 118 was below threshold
# 119 was below threshold
# 122 was below threshold
# 123 was below threshold
# 124 was below threshold
# 125 was below threshold
# 126 was below threshold
# 127 was below threshold
# 128 was below threshold
# 131 was below threshold
# 134 was below threshold
# 135 was below threshold
# 136 was below threshold
# 137 was below threshold
# 140 was below threshold
# 144 was below threshold
# 147 was below threshold
# 148 was below threshold
# 151 was below threshold
# 152 was below threshold
# 153 was below threshold
# 154 was below threshold
# 155 was below threshold
# 156 was below threshold
# 158 was below threshold
# 159 was below threshold
# 161 was below threshold
# 162 was below threshold
# 163 was below threshold
# 164 was below threshold
# 165 was below threshold
# 168 was below threshold
# 169 was below threshold
# 170 was below threshold
# 172 was below threshold
# 173 was below threshold
# 174 was below threshold
# 178 was below threshold
# 180 was below threshold
# 181 was below threshold
# 184 was below threshold
# 187 was below threshold
# 190 was below threshold
# 191 was below threshold
# 192 was below threshold
# 193 was below threshold
# 195 was below threshold
# 196 was below threshold
# 197 was below threshold
# 198 was below threshold
# 199 was below threshold
# 202 was below threshold
# 205 was below threshold
# 206 was below threshold
# 207 was below threshold
# 208 was below threshold
# 209 was below threshold
# 210 was below threshold
# 220 was below threshold
# 221 was below threshold
# 222 was below threshold
# 223 was below threshold
# 224 was below threshold
# 225 was below threshold
# 226 was below threshold
# 228 was below threshold
# 229 was below threshold
# 231 was below threshold
# 232 was below threshold
# 233 was below threshold
# 235 was below threshold
# 236 was below threshold
# 237 was below threshold
# 239 was below threshold
# 241 was below threshold
# 242 was below threshold
# 244 was below threshold
# 247 was below threshold
# 248 was below threshold
# 249 was below threshold
# 250 was below threshold
# 251 was below threshold
# 252 was below threshold
# 253 was below threshold
# 256 was below threshold
# 259 was below threshold
# 263 was below threshold
# 264 was below threshold
# 265 was below threshold
# 267 was below threshold
# 269 was below threshold
# 271 was below threshold
# 272 was below threshold
# 273 was below threshold
# 274 was below threshold
# 275 was below threshold
# 279 was below threshold
# 282 was below threshold
# 284 was below threshold
# 285 was below threshold
# 286 was below threshold
# 287 was below threshold
# 288 was below threshold
# 289 was below threshold
# 290 was below threshold
# 292 was below threshold
# 293 was below threshold
# 295 was below threshold
# 296 was below threshold
# 298 was below threshold
# 303 was below threshold
# 304 was below threshold
# 306 was below threshold
# 308 was below threshold
# 309 was below threshold
# 310 was below threshold
# 314 was below threshold
# 315 was below threshold
# 316 was below threshold
# 318 was below threshold
# 322 was below threshold
# 323 was below threshold
# 326 was below threshold
# 327 was below threshold
# 329 was below threshold
# 330 was below threshold
# 331 was below threshold
# 333 was below threshold
# 335 was below threshold
# 336 was below threshold
# 337 was below threshold
# 338 was below threshold
# 339 was below threshold
# 340 was below threshold
# 341 was below threshold
# 342 was below threshold
# 343 was below threshold
# 344 was below threshold
# 345 was below threshold
# 346 was below threshold
# 350 was below threshold
# 351 was below threshold
# 352 was below threshold
# 353 was below threshold
# 354 was below threshold
# 355 was below threshold
# 356 was below threshold
# 358 was below threshold
# 359 was below threshold
# 360 was below threshold
# 364 was below threshold
# 365 was below threshold
# 366 was below threshold
# 368 was below threshold
# 371 was below threshold
# 373 was below threshold
# 374 was below threshold
# 378 was below threshold
# 379 was below threshold
# 381 was below threshold
# 385 was below threshold
# 386 was below threshold
# 387 was below threshold
# 388 was below threshold
# 390 was below threshold
# 391 was below threshold
# 393 was below threshold
# 394 was below threshold
# 395 was below threshold
# 397 was below threshold
# 401 was below threshold
# 403 was below threshold
# 404 was below threshold
# 405 was below threshold
# 407 was below threshold
# 408 was below threshold
# 410 was below threshold
# 412 was below threshold
# 414 was below threshold
# 415 was below threshold
# 416 was below threshold
# 418 was below threshold
# 419 was below threshold
# 420 was below threshold
# 422 was below threshold
# 423 was below threshold
# 424 was below threshold
# 427 was below threshold
# 430 was below threshold
# 431 was below threshold
# 433 was below threshold
# 434 was below threshold
# 437 was below threshold
# 439 was below threshold
# 440 was below threshold
# 441 was below threshold
# 442 was below threshold
# 444 was below threshold
# 445 was below threshold
# 446 was below threshold
# 447 was below threshold
# 448 was below threshold
# 450 was below threshold
# 451 was below threshold
# 452 was below threshold
# 454 was below threshold
# 455 was below threshold
# 456 was below threshold
# 458 was below threshold
# 459 was below threshold
# 460 was below threshold
# 462 was below threshold
# 465 was below threshold
# 466 was below threshold
# 467 was below threshold
# 468 was below threshold
# 470 was below threshold
# 472 was below threshold
# 474 was below threshold
# 475 was below threshold
# 477 was below threshold
# 478 was below threshold
# 479 was below threshold
# 480 was below threshold
# 481 was below threshold
# 483 was below threshold
# 485 was below threshold
# 486 was below threshold
# 487 was below threshold
# 489 was below threshold
# 490 was below threshold
# 495 was below threshold
# 496 was below threshold
# 497 was below threshold
# 503 was below threshold
# 504 was below threshold
# 506 was below threshold
# 509 was below threshold
# 510 was below threshold
# 511 was below threshold
# 512 was below threshold
# 514 was below threshold
# 516 was below threshold
# 517 was below threshold
# 518 was below threshold
# 519 was below threshold
# 520 was below threshold
# 521 was below threshold
# 522 was below threshold
# 524 was below threshold
# 525 was below threshold
# 527 was below threshold
# 528 was below threshold
# 530 was below threshold
# 532 was below threshold
# 533 was below threshold
# 534 was below threshold
# 536 was below threshold
# 537 was below threshold
# 539 was below threshold
# 540 was below threshold
# 541 was below threshold
# 546 was below threshold
# 547 was below threshold
# 548 was below threshold
# 550 was below threshold
# 554 was below threshold
# 556 was below threshold
# 557 was below threshold
# 558 was below threshold
# 560 was below threshold
# 563 was below threshold
# 564 was below threshold
# 567 was below threshold
# 568 was below threshold
# 569 was below threshold
# 570 was below threshold
# 571 was below threshold
# 572 was below threshold
# 573 was below threshold
# 575 was below threshold
# 579 was below threshold
# 580 was below threshold
# 581 was below threshold
# 583 was below threshold
# 584 was below threshold
# 586 was below threshold
# 587 was below threshold
# 590 was below threshold
# 592 was below threshold
# 593 was below threshold
# 594 was below threshold
# 595 was below threshold
# 596 was below threshold
# 599 was below threshold
# 600 was below threshold
# 601 was below threshold
# 602 was below threshold
# 603 was below threshold
# 605 was below threshold
# 606 was below threshold
# 608 was below threshold
# 609 was below threshold
# 610 was below threshold
# 611 was below threshold
# 612 was below threshold
# 613 was below threshold
# 614 was below threshold
# 615 was below threshold
# 616 was below threshold
# 617 was below threshold
# 619 was below threshold
# 620 was below threshold
# 624 was below threshold
# 626 was below threshold
# 627 was below threshold
# 629 was below threshold
# 632 was below threshold
# 633 was below threshold
# 635 was below threshold
# 638 was below threshold
# 640 was below threshold
# 641 was below threshold
# 642 was below threshold
# 643 was below threshold
# 644 was below threshold
# 645 was below threshold
# 646 was below threshold
# 647 was below threshold
# 649 was below threshold
# 650 was below threshold
# 651 was below threshold
# 652 was below threshold
# 654 was below threshold
# 655 was below threshold
# 656 was below threshold
# 658 was below threshold
# 662 was below threshold
# 663 was below threshold
# 664 was below threshold
# 665 was below threshold
# 666 was below threshold
# 667 was below threshold
# 668 was below threshold
# 669 was below threshold
# 672 was below threshold
# 673 was below threshold
# 674 was below threshold
# 675 was below threshold
# 677 was below threshold
# 678 was below threshold
# 680 was below threshold
# 681 was below threshold
# 683 was below threshold
# 684 was below threshold
# 685 was below threshold
# 689 was below threshold
# 691 was below threshold
# 692 was below threshold
# 693 was below threshold
# 697 was below threshold
# 698 was below threshold
# 699 was below threshold
# 703 was below threshold
# 705 was below threshold
# 707 was below threshold
# 708 was below threshold
# 709 was below threshold
# 710 was below threshold
# 711 was below threshold
# 712 was below threshold
# 713 was below threshold
# 714 was below threshold
# 715 was below threshold
# 716 was below threshold
# 717 was below threshold
# 720 was below threshold
# 721 was below threshold
# 723 was below threshold
# 725 was below threshold
# 726 was below threshold
# 728 was below threshold
# 731 was below threshold
# 734 was below threshold
# 737 was below threshold
# 739 was below threshold
# 741 was below threshold
# 743 was below threshold
# 745 was below threshold
# 746 was below threshold
# 748 was below threshold
# 749 was below threshold
# 751 was below threshold
# 752 was below threshold
# 753 was below threshold
# 754 was below threshold
# 756 was below threshold
# 757 was below threshold
# 760 was below threshold
# 762 was below threshold
# 765 was below threshold
# 771 was below threshold
# 773 was below threshold
# 774 was below threshold
# 777 was below threshold
# 779 was below threshold
# 780 was below threshold
# 781 was below threshold
# 782 was below threshold
# 783 was below threshold
# 784 was below threshold
# 787 was below threshold
# 790 was below threshold
# 791 was below threshold
# 792 was below threshold
# 793 was below threshold
# 794 was below threshold
# 795 was below threshold
# 798 was below threshold
# 804 was below threshold
# 805 was below threshold
# 809 was below threshold
# 811 was below threshold
# 813 was below threshold
# 814 was below threshold
# 816 was below threshold
# 817 was below threshold
# 818 was below threshold
# 819 was below threshold
# 820 was below threshold
# 821 was below threshold
# 822 was below threshold
# 823 was below threshold
# 824 was below threshold
# 825 was below threshold
# 830 was below threshold
# 831 was below threshold
# 832 was below threshold
# 833 was below threshold
# 834 was below threshold
# 836 was below threshold
# 837 was below threshold
# 838 was below threshold
# 839 was below threshold
# 840 was below threshold
# 841 was below threshold
# 842 was below threshold
# 844 was below threshold
# 846 was below threshold
# 847 was below threshold
# 850 was below threshold
# 851 was below threshold
# 852 was below threshold
# 853 was below threshold
# 855 was below threshold
# 862 was below threshold
# 864 was below threshold
# 865 was below threshold
# 866 was below threshold
# 867 was below threshold
# 868 was below threshold
# 870 was below threshold
# 871 was below threshold
# 874 was below threshold
# 877 was below threshold
# 878 was below threshold
# 879 was below threshold
# 880 was below threshold
# 882 was below threshold
# 883 was below threshold
# 884 was below threshold
# 887 was below threshold
# 888 was below threshold
# 889 was below threshold
# 890 was below threshold
# 891 was below threshold
# 892 was below threshold
# 894 was below threshold
# 899 was below threshold
# 900 was below threshold

# %%
webp_qualities_dict.values()
# Out:
# dict_values([50, 41, 86, 56, 56, 68, 50, 44, 83, 29, 47, 71, 56, 35, 86, 53, 53, 74, 83, 44, 77, 74, 32, 71, 32, 62, 80, 95, 38, 83, 77, 29, 41, 32, 80, 29, 98, 74, 86, 35, 32, 62, 68, 77, 62, 77, 38, 41, 56, 56, 32, 35, 68, 92, 80, 44, 83, 38, 59, 44, 59, 65, 89, 38, 26, 74, 41, 86, 74, 86, 44, 86, 38, 80, 65, 47, 47, 71, 74, 59, 50, 83, 83, 38, 65, 47, 80, 77, 35, 47, 44, 53, 83, 89, 35, 32, 68, 62, 35, 68, 62, 35, 53, 80, 83, 86, 77, 29, 53, 32, 35, 71, 71, 47, 62, 86, 86, 68, 50, 89, 74, 53, 62, 68, 80, 50, 41, 32, 56, 29, 50, 53, 77, 77, 74, 77, 80, 77, 41, 74, 80, 32, 68, 68, 44, 74, 26, 71, 77, 65, 50, 74, 65, 62, 50, 89, 77, 89, 59, 50, 77, 68, 35, 56, 80, 71, 83, 59, 35, 86, 77, 83, 74, 47, 62, 65, 41, 59, 38, 32, 59, 74, 56, 65, 29, 62, 77, 38, 56, 50, 59, 35, 77, 80, 65, 53, 71, 35, 80, 59, 74, 65, 35, 62, 41, 68, 44, 53, 80, 35, 50, 89, 32, 38, 53, 47, 41, 53, 77, 59, 35, 50, 50, 68, 86, 74, 41, 62, 83, 83, 47, 74, 68, 77, 47, 38, 68, 38, 44, 83, 65, 38, 59, 53, 32, 59, 44, 53, 62, 80, 56, 29, 41, 38, 86, 35, 89, 62, 86, 35, 86, 38, 32, 86, 74, 32, 86, 71, 44, 68, 80, 77, 83, 53, 35, 59, 77, 41, 92, 77, 77, 83, 80, 80, 47, 56, 59, 38, 89, 68, 35, 74, 86, 62, 62, 68, 35, 89, 80, 86, 77, 44, 32, 41, 62, 44, 83, 56, 59, 68, 47, 74, 50, 80, 74, 68, 35, 83, 83, 74, 80, 32, 77, 74, 77, 62, 62, 68, 86, 65, 62, 86, 41, 74, 50, 44, 74, 56, 71, 68, 35, 29, 74, 62, 77, 74, 77, 77, 50, 47, 80, 29, 74, 80, 35, 47, 68, 50, 35, 35, 41, 68, 86, 44, 44, 41, 74, 41, 86, 50, 56, 41, 47, 44, 35, 47, 80, 92, 56, 41, 35, 50, 62, 77, 62, 38, 50, 56, 35, 38, 50, 50, 77, 44, 47, 56, 47, 47, 65, 44, 71, 86, 80, 32, 71, 68, 47, 56, 47, 44, 71, 59, 50, 62, 80, 47, 59, 50, 65, 35, 62, 74, 59, 56, 41, 56, 41, 65, 41, 32, 71, 56, 65, 56, 47, 89, 89, 80, 50, 44, 71, 68, 35, 47, 41, 74, 59, 35, 38, 47, 68, 74, 50, 44, 59, 47, 47, 35, 71, 53, 74, 59, 74, 53, 56, 77, 71, 53, 59, 59, 59, 56, 41, 83, 71, 47, 56, 59, 74, 32, 71, 77, 47, 74, 59, 47, 86, 80, 44, 62, 50, 59, 32, 44, 59, 77, 50, 62, 77, 71, 53, 47, 65, 62, 71, 44, 38, 38, 35, 35, 77, 86, 86, 56, 47, 50, 86, 68, 56, 44, 71, 95, 35, 44, 62, 62, 53, 74, 62, 71, 68, 62, 80, 50, 77, 44, 68, 77, 92, 77, 50, 59, 59, 32, 32, 32, 74, 65, 38, 68, 71, 89, 53, 53])
